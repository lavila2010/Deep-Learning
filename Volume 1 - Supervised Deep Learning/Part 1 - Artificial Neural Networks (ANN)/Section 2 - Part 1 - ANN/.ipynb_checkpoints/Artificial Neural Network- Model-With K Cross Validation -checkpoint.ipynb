# %% [markdown]
# ## Artificial Neural Network

# %% [markdown]
# #### Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# #### Importing the dataset

# %%
dataset = pd.read_csv('Churn_Modelling.csv')
X = dataset.iloc[:, 3:13].values
y = dataset.iloc[:, 13].values

# %%
dataset
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %% [markdown]
# #### Encoding categorical data

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder_X_1 = LabelEncoder()
X[:, 1] = labelencoder_X_1.fit_transform(X[:, 1])
labelencoder_X_2 = LabelEncoder()
X[:, 2] = labelencoder_X_2.fit_transform(X[:, 2])
onehotencoder = OneHotEncoder(categorical_features = [1])
X = onehotencoder.fit_transform(X).toarray()
X = X[:, 1:]
# Out:
# C:\Users\leandro\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\leandro\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:451: DeprecationWarning: The 'categorical_features' keyword is deprecated in version 0.20 and will be removed in 0.22. You can use the ColumnTransformer instead.
#   "use the ColumnTransformer instead.", DeprecationWarning)

# %% [markdown]
# #### Split the dataset into training and testset

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2 , random_state=0 )

# %% [markdown]
# #### Standard Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ### Part 2 - ANN Build up!

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
# Out:
# Using TensorFlow backend.

# %%
from keras.layers import Dropout

# %% [markdown]
# #### Initialising the ANN

# %%
classifier = Sequential()

# %% [markdown]
# #### Adding the input layer and the first hidden layer

# %%
classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu', input_dim = 11))
classifier.add(Dropout(p=0.1))
# Out:
# C:\Users\leandro\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Update your `Dropout` call to the Keras 2 API: `Dropout(rate=0.1)`

# %% [markdown]
# #### Adding the second hidden layer

# %%
classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))
classifier.add(Dropout(p=0.1))
# Out:
# C:\Users\leandro\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Update your `Dropout` call to the Keras 2 API: `Dropout(rate=0.1)`

# %% [markdown]
# #### Adding the output layer

# %%
classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# %% [markdown]
# #### Compiling the ANN

# %%
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# #### Fitting the ANN to the Training set

# %%
classifier.fit(X_train, y_train, batch_size = 10, epochs = 100)
# Out:
# Epoch 1/100
# 8000/8000 [==============================] - 1s 165us/step - loss: 0.5084 - accuracy: 0.7951
# Epoch 2/100
# 8000/8000 [==============================] - 1s 107us/step - loss: 0.4286 - accuracy: 0.8064
# Epoch 3/100
# 8000/8000 [==============================] - 1s 100us/step - loss: 0.4190 - accuracy: 0.8194
# Epoch 4/100
# 8000/8000 [==============================] - 1s 113us/step - loss: 0.4173 - accuracy: 0.8223
# Epoch 5/100
# 8000/8000 [==============================] - 1s 119us/step - loss: 0.4082 - accuracy: 0.8217
# Epoch 6/100
# 8000/8000 [==============================] - 1s 152us/step - loss: 0.4052 - accuracy: 0.8219
# Epoch 7/100
# 8000/8000 [==============================] - 1s 129us/step - loss: 0.4069 - accuracy: 0.8239
# Epoch 8/100
# 8000/8000 [==============================] - 1s 112us/step - loss: 0.4067 - accuracy: 0.8229
# Epoch 9/100
# 8000/8000 [==============================] - 1s 104us/step - loss: 0.4032 - accuracy: 0.8217
# Epoch 10/100
# 8000/8000 [==============================] - 1s 128us/step - loss: 0.4019 - accuracy: 0.8224
# Epoch 11/100
# 8000/8000 [==============================] - 1s 107us/step - loss: 0.4020 - accuracy: 0.8204
# Epoch 12/100
# 8000/8000 [==============================] - 1s 148us/step - loss: 0.4061 - accuracy: 0.8217
# Epoch 13/100
# 8000/8000 [==============================] - 1s 129us/step - loss: 0.4000 - accuracy: 0.8257
# Epoch 14/100
# 8000/8000 [==============================] - 1s 135us/step - loss: 0.3994 - accuracy: 0.8296
# Epoch 15/100
# 8000/8000 [==============================] - 1s 112us/step - loss: 0.3945 - accuracy: 0.8271
# Epoch 16/100
# 8000/8000 [==============================] - 1s 140us/step - loss: 0.3940 - accuracy: 0.8353
# Epoch 17/100
# 8000/8000 [==============================] - 1s 128us/step - loss: 0.3967 - accuracy: 0.8319
# Epoch 18/100
# 8000/8000 [==============================] - 1s 104us/step - loss: 0.3969 - accuracy: 0.8294
# Epoch 19/100
# 8000/8000 [==============================] - 1s 106us/step - loss: 0.3929 - accuracy: 0.8347
# Epoch 20/100
# 8000/8000 [==============================] - 1s 105us/step - loss: 0.3924 - accuracy: 0.8359
# Epoch 21/100
# 8000/8000 [==============================] - 1s 106us/step - loss: 0.3896 - accuracy: 0.8339
# Epoch 22/100
# 8000/8000 [==============================] - 1s 107us/step - loss: 0.3930 - accuracy: 0.8315
# Epoch 23/100
# 8000/8000 [==============================] - 1s 140us/step - loss: 0.3952 - accuracy: 0.8324
# Epoch 24/100
# 8000/8000 [==============================] - 1s 149us/step - loss: 0.3937 - accuracy: 0.8331
# Epoch 25/100
# 8000/8000 [==============================] - 1s 109us/step - loss: 0.3954 - accuracy: 0.8341
# Epoch 26/100
# 8000/8000 [==============================] - 1s 106us/step - loss: 0.3920 - accuracy: 0.8324
# Epoch 27/100
# 8000/8000 [==============================] - 1s 115us/step - loss: 0.3925 - accuracy: 0.8334
# Epoch 28/100
# 8000/8000 [==============================] - 1s 107us/step - loss: 0.3916 - accuracy: 0.8341
# Epoch 29/100
# 8000/8000 [==============================] - 1s 141us/step - loss: 0.3921 - accuracy: 0.8369
# Epoch 30/100
# 8000/8000 [==============================] - 1s 115us/step - loss: 0.3899 - accuracy: 0.8354
# Epoch 31/100
# 8000/8000 [==============================] - 1s 109us/step - loss: 0.3912 - accuracy: 0.8410
# Epoch 32/100
# 8000/8000 [==============================] - 1s 106us/step - loss: 0.3933 - accuracy: 0.8355
# Epoch 33/100
# 8000/8000 [==============================] - 1s 108us/step - loss: 0.3872 - accuracy: 0.8376
# Epoch 34/100
# 8000/8000 [==============================] - 1s 103us/step - loss: 0.3895 - accuracy: 0.8359
# Epoch 35/100
# 8000/8000 [==============================] - 1s 134us/step - loss: 0.3941 - accuracy: 0.8317
# Epoch 36/100
# 8000/8000 [==============================] - 1s 109us/step - loss: 0.3905 - accuracy: 0.8357
# Epoch 37/100
# 8000/8000 [==============================] - 1s 109us/step - loss: 0.3902 - accuracy: 0.8351
# Epoch 38/100
# 8000/8000 [==============================] - 1s 106us/step - loss: 0.3834 - accuracy: 0.8350
# Epoch 39/100
# 8000/8000 [==============================] - 1s 111us/step - loss: 0.3904 - accuracy: 0.8360
# Epoch 40/100
# 8000/8000 [==============================] - 1s 107us/step - loss: 0.3892 - accuracy: 0.8371
# Epoch 41/100
# 8000/8000 [==============================] - 1s 156us/step - loss: 0.3876 - accuracy: 0.8371
# Epoch 42/100
# 8000/8000 [==============================] - 1s 112us/step - loss: 0.3882 - accuracy: 0.8374
# Epoch 43/100
# 8000/8000 [==============================] - 1s 140us/step - loss: 0.3877 - accuracy: 0.8376
# Epoch 44/100
# 8000/8000 [==============================] - 1s 132us/step - loss: 0.3887 - accuracy: 0.8370
# Epoch 45/100
# 8000/8000 [==============================] - 1s 99us/step - loss: 0.3839 - accuracy: 0.8410
# Epoch 46/100
# 8000/8000 [==============================] - 1s 180us/step - loss: 0.3889 - accuracy: 0.8386
# Epoch 47/100
# 8000/8000 [==============================] - 1s 177us/step - loss: 0.3882 - accuracy: 0.8360
# Epoch 48/100
# 8000/8000 [==============================] - 1s 133us/step - loss: 0.3839 - accuracy: 0.8375
# Epoch 49/100
# 8000/8000 [==============================] - 2s 198us/step - loss: 0.3860 - accuracy: 0.8389
# Epoch 50/100
# 8000/8000 [==============================] - 1s 139us/step - loss: 0.3909 - accuracy: 0.8364
# Epoch 51/100
# 8000/8000 [==============================] - 1s 99us/step - loss: 0.3900 - accuracy: 0.8393
# Epoch 52/100
# 8000/8000 [==============================] - 1s 102us/step - loss: 0.3862 - accuracy: 0.8388
# Epoch 53/100
# 8000/8000 [==============================] - 1s 106us/step - loss: 0.3903 - accuracy: 0.8386
# Epoch 54/100
# 8000/8000 [==============================] - 1s 111us/step - loss: 0.3885 - accuracy: 0.8394
# Epoch 55/100
# 8000/8000 [==============================] - 2s 239us/step - loss: 0.3887 - accuracy: 0.8376
# Epoch 56/100
# 8000/8000 [==============================] - 1s 187us/step - loss: 0.3882 - accuracy: 0.8384
# Epoch 57/100
# 8000/8000 [==============================] - 2s 200us/step - loss: 0.3852 - accuracy: 0.8389
# Epoch 58/100
# 8000/8000 [==============================] - 1s 151us/step - loss: 0.3859 - accuracy: 0.8401
# Epoch 59/100
# 8000/8000 [==============================] - 1s 129us/step - loss: 0.3866 - accuracy: 0.8397
# Epoch 60/100
# 8000/8000 [==============================] - 1s 128us/step - loss: 0.3894 - accuracy: 0.8399
# Epoch 61/100
# 8000/8000 [==============================] - 1s 101us/step - loss: 0.3866 - accuracy: 0.8360
# Epoch 62/100
# 8000/8000 [==============================] - 1s 87us/step - loss: 0.3880 - accuracy: 0.8370
# Epoch 63/100
# 8000/8000 [==============================] - 1s 112us/step - loss: 0.3859 - accuracy: 0.8391
# Epoch 64/100
# 8000/8000 [==============================] - 1s 104us/step - loss: 0.3850 - accuracy: 0.8397
# Epoch 65/100
# 8000/8000 [==============================] - 1s 98us/step - loss: 0.3907 - accuracy: 0.8345
# Epoch 66/100
# 8000/8000 [==============================] - 1s 133us/step - loss: 0.3905 - accuracy: 0.8386
# Epoch 67/100
# 8000/8000 [==============================] - 1s 112us/step - loss: 0.3888 - accuracy: 0.8369
# Epoch 68/100
# 8000/8000 [==============================] - 1s 89us/step - loss: 0.3875 - accuracy: 0.8369
# Epoch 69/100
# 8000/8000 [==============================] - 1s 90us/step - loss: 0.3903 - accuracy: 0.8378
# Epoch 70/100
# 8000/8000 [==============================] - 1s 88us/step - loss: 0.3868 - accuracy: 0.8400
# Epoch 71/100
# 8000/8000 [==============================] - 1s 98us/step - loss: 0.3867 - accuracy: 0.8389
# Epoch 72/100
# 8000/8000 [==============================] - 1s 114us/step - loss: 0.3938 - accuracy: 0.8379
# Epoch 73/100
# 8000/8000 [==============================] - 1s 146us/step - loss: 0.3888 - accuracy: 0.8376
# Epoch 74/100
# 8000/8000 [==============================] - 1s 104us/step - loss: 0.3874 - accuracy: 0.8391
# Epoch 75/100
# 8000/8000 [==============================] - 1s 97us/step - loss: 0.3872 - accuracy: 0.8385
# Epoch 76/100
# 8000/8000 [==============================] - 1s 88us/step - loss: 0.3850 - accuracy: 0.8370
# Epoch 77/100
# 8000/8000 [==============================] - 1s 88us/step - loss: 0.3866 - accuracy: 0.8375
# Epoch 78/100
# 8000/8000 [==============================] - 1s 84us/step - loss: 0.3875 - accuracy: 0.8386
# Epoch 79/100
# 8000/8000 [==============================] - 1s 96us/step - loss: 0.3916 - accuracy: 0.8366
# Epoch 80/100
# 8000/8000 [==============================] - 1s 110us/step - loss: 0.3896 - accuracy: 0.8364
# Epoch 81/100
# 8000/8000 [==============================] - 1s 91us/step - loss: 0.3889 - accuracy: 0.8375
# Epoch 82/100
# 8000/8000 [==============================] - 1s 87us/step - loss: 0.3823 - accuracy: 0.8371
# Epoch 83/100
# 8000/8000 [==============================] - 1s 87us/step - loss: 0.3911 - accuracy: 0.8345
# Epoch 84/100
# 8000/8000 [==============================] - 1s 87us/step - loss: 0.3869 - accuracy: 0.8376
# Epoch 85/100
# 8000/8000 [==============================] - 1s 102us/step - loss: 0.3889 - accuracy: 0.8366
# Epoch 86/100
# 8000/8000 [==============================] - 1s 96us/step - loss: 0.3887 - accuracy: 0.8372
# Epoch 87/100
# 8000/8000 [==============================] - 1s 106us/step - loss: 0.3890 - accuracy: 0.8374
# Epoch 88/100
# 8000/8000 [==============================] - 1s 88us/step - loss: 0.3907 - accuracy: 0.8356
# Epoch 89/100
# 8000/8000 [==============================] - 1s 87us/step - loss: 0.3874 - accuracy: 0.8376
# Epoch 90/100
# 8000/8000 [==============================] - 1s 88us/step - loss: 0.3891 - accuracy: 0.8356
# Epoch 91/100
# 8000/8000 [==============================] - 1s 87us/step - loss: 0.3891 - accuracy: 0.8374
# Epoch 92/100
# 8000/8000 [==============================] - 1s 123us/step - loss: 0.3895 - accuracy: 0.8380
# Epoch 93/100
# 8000/8000 [==============================] - 1s 117us/step - loss: 0.3874 - accuracy: 0.8388
# Epoch 94/100
# 8000/8000 [==============================] - 1s 107us/step - loss: 0.3893 - accuracy: 0.8396
# Epoch 95/100
# 8000/8000 [==============================] - 1s 118us/step - loss: 0.3891 - accuracy: 0.8391
# Epoch 96/100
# 8000/8000 [==============================] - 1s 98us/step - loss: 0.3876 - accuracy: 0.8344
# Epoch 97/100
# 8000/8000 [==============================] - 1s 94us/step - loss: 0.3872 - accuracy: 0.8376
# Epoch 98/100
# 8000/8000 [==============================] - 1s 94us/step - loss: 0.3833 - accuracy: 0.8379
# Epoch 99/100
# 8000/8000 [==============================] - 1s 101us/step - loss: 0.3859 - accuracy: 0.8396
# Epoch 100/100
# 8000/8000 [==============================] - 1s 104us/step - loss: 0.3868 - accuracy: 0.8384

# %% [markdown]
# ### Part 3 - Making predictions and evaluating the model

# %% [markdown]
# #### Predicting the Test set results

# %%
y_pred = classifier.predict(X_test)

# %%
prediction=list(y_pred)

# %%
prediction
# Out:
# [array([0.2615227], dtype=float32),
#  array([0.2496891], dtype=float32),
#  array([0.11187033], dtype=float32),
#  array([0.06336541], dtype=float32),
#  array([0.15015437], dtype=float32),
#  array([0.66830105], dtype=float32),
#  array([0.06381523], dtype=float32),
#  array([0.13463014], dtype=float32),
#  array([0.4186971], dtype=float32),
#  array([0.66830105], dtype=float32),
#  array([0.0541795], dtype=float32),
#  array([0.35848844], dtype=float32),
#  array([0.28746396], dtype=float32),
#  array([0.22701588], dtype=float32),
#  array([0.55237585], dtype=float32),
#  array([0.26178855], dtype=float32),
#  array([0.1924445], dtype=float32),
#  array([0.1596198], dtype=float32),
#  array([0.06464253], dtype=float32),
#  array([0.1423375], dtype=float32),
#  array([0.3530365], dtype=float32),
#  array([0.02397625], dtype=float32),
#  array([0.09964099], dtype=float32),
#  array([0.10424743], dtype=float32),
#  array([0.02055535], dtype=float32),
#  array([0.2218507], dtype=float32),
#  array([0.1574685], dtype=float32),
#  array([0.09019355], dtype=float32),
#  array([0.21916178], dtype=float32),
#  array([0.2896069], dtype=float32),
#  array([0.05411632], dtype=float32),
#  array([0.3530365], dtype=float32),
#  array([0.07770117], dtype=float32),
#  array([0.06500641], dtype=float32),
#  array([0.300345], dtype=float32),
#  array([0.04057081], dtype=float32),
#  array([0.05546438], dtype=float32),
#  array([0.03246385], dtype=float32),
#  array([0.04991106], dtype=float32),
#  array([0.06929947], dtype=float32),
#  array([0.09578384], dtype=float32),
#  array([0.32581356], dtype=float32),
#  array([0.30380931], dtype=float32),
#  array([0.04396316], dtype=float32),
#  array([0.3530365], dtype=float32),
#  array([0.02137702], dtype=float32),
#  array([0.2076338], dtype=float32),
#  array([0.06881634], dtype=float32),
#  array([0.2496626], dtype=float32),
#  array([0.01241772], dtype=float32),
#  array([0.66830105], dtype=float32),
#  array([0.01913127], dtype=float32),
#  array([0.06063045], dtype=float32),
#  array([0.15027553], dtype=float32),
#  array([0.25597233], dtype=float32),
#  array([0.09730396], dtype=float32),
#  array([0.27440858], dtype=float32),
#  array([0.27280423], dtype=float32),
#  array([0.43779585], dtype=float32),
#  array([0.35290462], dtype=float32),
#  array([0.14902458], dtype=float32),
#  array([0.1912438], dtype=float32),
#  array([0.02733738], dtype=float32),
#  array([0.11725944], dtype=float32),
#  array([0.36871904], dtype=float32),
#  array([0.897703], dtype=float32),
#  array([0.11370015], dtype=float32),
#  array([0.2460918], dtype=float32),
#  array([0.13616212], dtype=float32),
#  array([0.8749723], dtype=float32),
#  array([0.70487165], dtype=float32),
#  array([0.04449346], dtype=float32),
#  array([0.01227813], dtype=float32),
#  array([0.9245064], dtype=float32),
#  array([0.3530365], dtype=float32),
#  array([0.11008844], dtype=float32),
#  array([0.65028614], dtype=float32),
#  array([0.01680587], dtype=float32),
#  array([0.07850436], dtype=float32),
#  array([0.13960496], dtype=float32),
#  array([0.7962337], dtype=float32),
#  array([0.38671726], dtype=float32),
#  array([0.05156211], dtype=float32),
#  array([0.05423186], dtype=float32),
#  array([0.62248933], dtype=float32),
#  array([0.11984821], dtype=float32),
#  array([0.07375649], dtype=float32),
#  array([0.04733844], dtype=float32),
#  array([0.5382176], dtype=float32),
#  array([0.06298499], dtype=float32),
#  array([0.3415376], dtype=float32),
#  array([0.4843841], dtype=float32),
#  array([0.2054082], dtype=float32),
#  array([0.40304145], dtype=float32),
#  array([0.02133807], dtype=float32),
#  array([0.3455458], dtype=float32),
#  array([0.06617611], dtype=float32),
#  array([0.18579227], dtype=float32),
#  array([0.16289562], dtype=float32),
#  array([0.29931498], dtype=float32),
#  array([0.01210286], dtype=float32),
#  array([0.31250045], dtype=float32),
#  array([0.08313074], dtype=float32),
#  array([0.09709654], dtype=float32),
#  array([0.08144692], dtype=float32),
#  array([0.11893471], dtype=float32),
#  array([0.03848905], dtype=float32),
#  array([0.04535177], dtype=float32),
#  array([0.23627502], dtype=float32),
#  array([0.10268918], dtype=float32),
#  array([0.2669074], dtype=float32),
#  array([0.66830105], dtype=float32),
#  array([0.13141982], dtype=float32),
#  array([0.08749358], dtype=float32),
#  array([0.6400642], dtype=float32),
#  array([0.04948597], dtype=float32),
#  array([0.05811982], dtype=float32),
#  array([0.3530365], dtype=float32),
#  array([0.09408522], dtype=float32),
#  array([0.01098585], dtype=float32),
#  array([0.20297395], dtype=float32),
#  array([0.2378786], dtype=float32),
#  array([0.5160342], dtype=float32),
#  array([0.05736051], dtype=float32),
#  array([0.0618666], dtype=float32),
#  array([0.51053816], dtype=float32),
#  array([0.3530365], dtype=float32),
#  array([0.39254287], dtype=float32),
#  array([0.41193828], dtype=float32),
#  array([0.29502052], dtype=float32),
#  array([0.09777651], dtype=float32),
#  array([0.37591556], dtype=float32),
#  array([0.18504618], dtype=float32),
#  array([0.03183104], dtype=float32),
#  array([0.28752667], dtype=float32),
#  array([0.20632754], dtype=float32),
#  array([0.17040025], dtype=float32),
#  array([0.22149593], dtype=float32),
#  array([0.01658078], dtype=float32),
#  array([0.0351398], dtype=float32),
#  array([0.05563129], dtype=float32),
#  array([0.01606276], dtype=float32),
#  array([0.4752497], dtype=float32),
#  array([0.15642375], dtype=float32),
#  array([0.08978225], dtype=float32),
#  array([0.3530365], dtype=float32),
#  array([0.04789553], dtype=float32),
#  array([0.6266932], dtype=float32),
#  array([0.20342076], dtype=float32),
#  array([0.8939702], dtype=float32),
#  array([0.11490703], dtype=float32),
#  array([0.10429437], dtype=float32),
#  array([0.02588597], dtype=float32),
#  array([0.1652538], dtype=float32),
#  array([0.93357915], dtype=float32),
#  array([0.6039418], dtype=float32),
#  array([0.22391255], dtype=float32),
#  array([0.2519585], dtype=float32),
#  array([0.28495967], dtype=float32),
#  array([0.15786932], dtype=float32),
#  array([0.08194967], dtype=float32),
#  array([0.15201893], dtype=float32),
#  array([0.06308807], dtype=float32),
#  array([0.2537823], dtype=float32),
#  array([0.01225784], dtype=float32),
#  array([0.05580118], dtype=float32),
#  array([0.15179421], dtype=float32),
#  array([0.08569515], dtype=float32),
#  array([0.612497], dtype=float32),
#  array([0.02655946], dtype=float32),
#  array([0.03436378], dtype=float32),
#  array([0.17187668], dtype=float32),
#  array([0.10882928], dtype=float32),
#  array([0.31574413], dtype=float32),
#  array([0.32760748], dtype=float32),
#  array([0.07775463], dtype=float32),
#  array([0.15794854], dtype=float32),
#  array([0.03488718], dtype=float32),
#  array([0.02188143], dtype=float32),
#  array([0.00944639], dtype=float32),
#  array([0.08053158], dtype=float32),
#  array([0.08064291], dtype=float32),
#  array([0.66830105], dtype=float32),
#  array([0.21475904], dtype=float32),
#  array([0.06848226], dtype=float32),
#  array([0.57949233], dtype=float32),
#  array([0.06661341], dtype=float32),
#  array([0.1419011], dtype=float32),
#  array([0.19317015], dtype=float32),
#  array([0.01579366], dtype=float32),
#  array([0.5822944], dtype=float32),
#  array([0.12614174], dtype=float32),
#  array([0.00884552], dtype=float32),
#  array([0.27454585], dtype=float32),
#  array([0.08606569], dtype=float32),
#  array([0.04426196], dtype=float32),
#  array([0.17637834], dtype=float32),
#  array([0.6047112], dtype=float32),
#  array([0.18385987], dtype=float32),
#  array([0.09733044], dtype=float32),
#  array([0.1104422], dtype=float32),
#  array([0.18986684], dtype=float32),
#  array([0.41058117], dtype=float32),
#  array([0.60144484], dtype=float32),
#  array([0.08560158], dtype=float32),
#  array([0.1510628], dtype=float32),
#  array([0.04176586], dtype=float32),
#  array([0.41401032], dtype=float32),
#  array([0.07467783], dtype=float32),
#  array([0.04357094], dtype=float32),
#  array([0.06945463], dtype=float32),
#  array([0.08305667], dtype=float32),
#  array([0.74201995], dtype=float32),
#  array([0.66830105], dtype=float32),
#  array([0.17964283], dtype=float32),
#  array([0.1648945], dtype=float32),
#  array([0.02776573], dtype=float32),
#  array([0.15091704], dtype=float32),
#  array([0.05183923], dtype=float32),
#  array([0.04705996], dtype=float32),
#  array([0.29674965], dtype=float32),
#  array([0.23648982], dtype=float32),
#  array([0.08001401], dtype=float32),
#  array([0.20593877], dtype=float32),
#  array([0.0923875], dtype=float32),
#  array([0.10286155], dtype=float32),
#  array([0.03988583], dtype=float32),
#  array([0.13967013], dtype=float32),
#  array([0.05917732], dtype=float32),
#  array([0.35866925], dtype=float32),
#  array([0.0769603], dtype=float32),
#  array([0.05149185], dtype=float32),
#  array([0.08792117], dtype=float32),
#  array([0.01360171], dtype=float32),
#  array([0.03415682], dtype=float32),
#  array([0.08173187], dtype=float32),
#  array([0.11515459], dtype=float32),
#  array([0.3530365], dtype=float32),
#  array([0.29117453], dtype=float32),
#  array([0.15194261], dtype=float32),
#  array([0.15492865], dtype=float32),
#  array([0.31640127], dtype=float32),
#  array([0.16964021], dtype=float32),
#  array([0.27021757], dtype=float32),
#  array([0.06147426], dtype=float32),
#  array([0.06576482], dtype=float32),
#  array([0.05300535], dtype=float32),
#  array([0.28072017], dtype=float32),
#  array([0.07365022], dtype=float32),
#  array([0.0821168], dtype=float32),
#  array([0.0203955], dtype=float32),
#  array([0.6652871], dtype=float32),
#  array([0.10591491], dtype=float32),
#  array([0.78111655], dtype=float32),
#  array([0.03120843], dtype=float32),
#  array([0.12614787], dtype=float32),
#  array([0.00686867], dtype=float32),
#  array([0.1946827], dtype=float32),
#  array([0.04576769], dtype=float32),
#  array([0.07128975], dtype=float32),
#  array([0.13701145], dtype=float32),
#  array([0.33520773], dtype=float32),
#  array([0.2831095], dtype=float32),
#  array([0.11078434], dtype=float32),
#  array([0.10669659], dtype=float32),
#  array([0.06899418], dtype=float32),
#  array([0.05089238], dtype=float32),
#  array([0.21002191], dtype=float32),
#  array([0.05983769], dtype=float32),
#  array([0.03107684], dtype=float32),
#  array([0.3530365], dtype=float32),
#  array([0.01835691], dtype=float32),
#  array([0.30666262], dtype=float32),
#  array([0.87321144], dtype=float32),
#  array([0.0915843], dtype=float32),
#  array([0.19257347], dtype=float32),
#  array([0.0217815], dtype=float32),
#  array([0.12289608], dtype=float32),
#  array([0.14912757], dtype=float32),
#  array([0.46599224], dtype=float32),
#  array([0.09491166], dtype=float32),
#  array([0.12112945], dtype=float32),
#  array([0.5535809], dtype=float32),
#  array([0.15381388], dtype=float32),
#  array([0.02309174], dtype=float32),
#  array([0.15216148], dtype=float32),
#  array([0.17061347], dtype=float32),
#  array([0.23958315], dtype=float32),
#  array([0.0298017], dtype=float32),
#  array([0.10134157], dtype=float32),
#  array([0.0110048], dtype=float32),
#  array([0.1343509], dtype=float32),
#  array([0.11904046], dtype=float32),
#  array([0.43836376], dtype=float32),
#  array([0.12535012], dtype=float32),
#  array([0.10737545], dtype=float32),
#  array([0.02072762], dtype=float32),
#  array([0.0815946], dtype=float32),
#  array([0.1632738], dtype=float32),
#  array([0.2818091], dtype=float32),
#  array([0.04522898], dtype=float32),
#  array([0.27173978], dtype=float32),
#  array([0.26803908], dtype=float32),
#  array([0.61197734], dtype=float32),
#  array([0.02376186], dtype=float32),
#  array([0.30691543], dtype=float32),
#  array([0.11523479], dtype=float32),
#  array([0.01952309], dtype=float32),
#  array([0.8576908], dtype=float32),
#  array([0.10522225], dtype=float32),
#  array([0.08154132], dtype=float32),
#  array([0.3530365], dtype=float32),
#  array([0.33233094], dtype=float32),
#  array([0.04936009], dtype=float32),
#  array([0.04067228], dtype=float32),
#  array([0.53560275], dtype=float32),
#  array([0.08686579], dtype=float32),
#  array([0.1474946], dtype=float32),
#  array([0.66830105], dtype=float32),
#  array([0.21790195], dtype=float32),
#  array([0.9112955], dtype=float32),
#  array([0.03565075], dtype=float32),
#  array([0.01702445], dtype=float32),
#  array([0.66830105], dtype=float32),
#  array([0.3271202], dtype=float32),
#  array([0.13034989], dtype=float32),
#  array([0.10001596], dtype=float32),
#  array([0.18624888], dtype=float32),
#  array([0.11505792], dtype=float32),
#  array([0.16958863], dtype=float32),
#  array([0.01509849], dtype=float32),
#  array([0.06845021], dtype=float32),
#  array([0.16239013], dtype=float32),
#  array([0.03253675], dtype=float32),
#  array([0.04619451], dtype=float32),
#  array([0.05956879], dtype=float32),
#  array([0.32019734], dtype=float32),
#  array([0.00964046], dtype=float32),
#  array([0.07695629], dtype=float32),
#  array([0.04752079], dtype=float32),
#  array([0.1598359], dtype=float32),
#  array([0.66830105], dtype=float32),
#  array([0.24933614], dtype=float32),
#  array([0.56674784], dtype=float32),
#  array([0.03808839], dtype=float32),
#  array([0.35012928], dtype=float32),
#  array([0.20538324], dtype=float32),
#  array([0.20926122], dtype=float32),
#  array([0.06808461], dtype=float32),
#  array([0.16227844], dtype=float32),
#  array([0.02520972], dtype=float32),
#  array([0.02834901], dtype=float32),
#  array([0.01932857], dtype=float32),
#  array([0.6103973], dtype=float32),
#  array([0.3820439], dtype=float32),
#  array([0.4714711], dtype=float32),
#  array([0.14904599], dtype=float32),
#  array([0.32085153], dtype=float32),
#  array([0.34337822], dtype=float32),
#  array([0.02214617], dtype=float32),
#  array([0.18503985], dtype=float32),
#  array([0.29323637], dtype=float32),
#  array([0.08303931], dtype=float32),
#  array([0.5354006], dtype=float32),
#  array([0.3530365], dtype=float32),
#  array([0.9055872], dtype=float32),
#  array([0.08585763], dtype=float32),
#  array([0.3530365], dtype=float32),
#  array([0.05460151], dtype=float32),
#  array([0.05715002], dtype=float32),
#  array([0.03265965], dtype=float32),
#  array([0.1304235], dtype=float32),
#  array([0.3408913], dtype=float32),
#  array([0.1619911], dtype=float32),
#  array([0.12412827], dtype=float32),
#  array([0.01414135], dtype=float32),
#  array([0.18070982], dtype=float32),
#  array([0.68720084], dtype=float32),
#  array([0.08929925], dtype=float32),
#  array([0.01823218], dtype=float32),
#  array([0.29042485], dtype=float32),
#  array([0.03838842], dtype=float32),
#  array([0.34554002], dtype=float32),
#  array([0.4048867], dtype=float32),
#  array([0.04545501], dtype=float32),
#  array([0.1062625], dtype=float32),
#  array([0.71454054], dtype=float32),
#  array([0.57984126], dtype=float32),
#  array([0.5653278], dtype=float32),
#  array([0.22197704], dtype=float32),
#  array([0.27074018], dtype=float32),
#  array([0.28245437], dtype=float32),
#  array([0.03944843], dtype=float32),
#  array([0.02325077], dtype=float32),
#  array([0.11068176], dtype=float32),
#  array([0.15830156], dtype=float32),
#  array([0.19682246], dtype=float32),
#  array([0.14261606], dtype=float32),
#  array([0.12520063], dtype=float32),
#  array([0.02748606], dtype=float32),
#  array([0.03149918], dtype=float32),
#  array([0.24306], dtype=float32),
#  array([0.15316096], dtype=float32),
#  array([0.0365881], dtype=float32),
#  array([0.03830758], dtype=float32),
#  array([0.66830105], dtype=float32),
#  array([0.04634079], dtype=float32),
#  array([0.058274], dtype=float32),
#  array([0.33560306], dtype=float32),
#  array([0.19230343], dtype=float32),
#  array([0.09222526], dtype=float32),
#  array([0.09889337], dtype=float32),
#  array([0.13311934], dtype=float32),
#  array([0.10458411], dtype=float32),
#  array([0.08074124], dtype=float32),
#  array([0.13946813], dtype=float32),
#  array([0.33777627], dtype=float32),
#  array([0.10380308], dtype=float32),
#  array([0.3530365], dtype=float32),
#  array([0.4718621], dtype=float32),
#  array([0.01283427], dtype=float32),
#  array([0.14909546], dtype=float32),
#  array([0.15443362], dtype=float32),
#  array([0.21001357], dtype=float32),
#  array([0.2392033], dtype=float32),
#  array([0.10366752], dtype=float32),
#  array([0.2454571], dtype=float32),
#  array([0.05068673], dtype=float32),
#  array([0.03869329], dtype=float32),
#  array([0.24785984], dtype=float32),
#  array([0.33140323], dtype=float32),
#  array([0.06813324], dtype=float32),
#  array([0.8522138], dtype=float32),
#  array([0.1104806], dtype=float32),
#  array([0.68220776], dtype=float32),
#  array([0.04509246], dtype=float32),
#  array([0.35427225], dtype=float32),
#  array([0.05014189], dtype=float32),
#  array([0.04668479], dtype=float32),
#  array([0.00729002], dtype=float32),
#  array([0.18707047], dtype=float32),
#  array([0.03191591], dtype=float32),
#  array([0.17855056], dtype=float32),
#  array([0.01046095], dtype=float32),
#  array([0.08016992], dtype=float32),
#  array([0.32880506], dtype=float32),
#  array([0.05767665], dtype=float32),
#  array([0.56547797], dtype=float32),
#  array([0.04665382], dtype=float32),
#  array([0.03702314], dtype=float32),
#  array([0.19176549], dtype=float32),
#  array([0.03563605], dtype=float32),
#  array([0.80757666], dtype=float32),
#  array([0.47371438], dtype=float32),
#  array([0.6231179], dtype=float32),
#  array([0.15845153], dtype=float32),
#  array([0.09107537], dtype=float32),
#  array([0.12704635], dtype=float32),
#  array([0.03572184], dtype=float32),
#  array([0.3123997], dtype=float32),
#  array([0.01574541], dtype=float32),
#  array([0.07726339], dtype=float32),
#  array([0.22622032], dtype=float32),
#  array([0.09601592], dtype=float32),
#  array([0.03016485], dtype=float32),
#  array([0.89195514], dtype=float32),
#  array([0.08811818], dtype=float32),
#  array([0.7057991], dtype=float32),
#  array([0.0748872], dtype=float32),
#  array([0.2112373], dtype=float32),
#  array([0.14457406], dtype=float32),
#  array([0.5333169], dtype=float32),
#  array([0.34377536], dtype=float32),
#  array([0.69544226], dtype=float32),
#  array([0.06572924], dtype=float32),
#  array([0.07935677], dtype=float32),
#  array([0.2287067], dtype=float32),
#  array([0.3530365], dtype=float32),
#  array([0.13138922], dtype=float32),
#  array([0.36451164], dtype=float32),
#  array([0.10553158], dtype=float32),
#  array([0.86448216], dtype=float32),
#  array([0.1462924], dtype=float32),
#  array([0.19499186], dtype=float32),
#  array([0.02420813], dtype=float32),
#  array([0.6856028], dtype=float32),
#  array([0.34408358], dtype=float32),
#  array([0.06015506], dtype=float32),
#  array([0.21336637], dtype=float32),
#  array([0.16877158], dtype=float32),
#  array([0.7853695], dtype=float32),
#  array([0.6403245], dtype=float32),
#  array([0.05701874], dtype=float32),
#  array([0.13088034], dtype=float32),
#  array([0.04952091], dtype=float32),
#  array([0.07857348], dtype=float32),
#  array([0.09937881], dtype=float32),
#  array([0.20106152], dtype=float32),
#  array([0.15122864], dtype=float32),
#  array([0.02437306], dtype=float32),
#  array([0.3530365], dtype=float32),
#  array([0.09149798], dtype=float32),
#  array([0.45973852], dtype=float32),
#  array([0.13358957], dtype=float32),
#  array([0.77407104], dtype=float32),
#  array([0.0868419], dtype=float32),
#  array([0.09428639], dtype=float32),
#  array([0.08645765], dtype=float32),
#  array([0.16114934], dtype=float32),
#  array([0.28935096], dtype=float32),
#  array([0.12067922], dtype=float32),
#  array([0.05351162], dtype=float32),
#  array([0.06507084], dtype=float32),
#  array([0.66830105], dtype=float32),
#  array([0.23119904], dtype=float32),
#  array([0.11359193], dtype=float32),
#  array([0.1511162], dtype=float32),
#  array([0.03111171], dtype=float32),
#  array([0.17921263], dtype=float32),
#  array([0.1456811], dtype=float32),
#  array([0.23539332], dtype=float32),
#  array([0.04620783], dtype=float32),
#  array([0.10199971], dtype=float32),
#  array([0.0103551], dtype=float32),
#  array([0.11907931], dtype=float32),
#  array([0.1742771], dtype=float32),
#  array([0.12494486], dtype=float32),
#  array([0.10012615], dtype=float32),
#  array([0.09803365], dtype=float32),
#  array([0.03259033], dtype=float32),
#  array([0.04131033], dtype=float32),
#  array([0.26518512], dtype=float32),
#  array([0.13057008], dtype=float32),
#  array([0.18903053], dtype=float32),
#  array([0.35067046], dtype=float32),
#  array([0.14743145], dtype=float32),
#  array([0.14096151], dtype=float32),
#  array([0.10807509], dtype=float32),
#  array([0.24486858], dtype=float32),
#  array([0.13288155], dtype=float32),
#  array([0.18669204], dtype=float32),
#  array([0.08081429], dtype=float32),
#  array([0.03588208], dtype=float32),
#  array([0.23552534], dtype=float32),
#  array([0.04968473], dtype=float32),
#  array([0.05227792], dtype=float32),
#  array([0.22959383], dtype=float32),
#  array([0.23501287], dtype=float32),
#  array([0.03647963], dtype=float32),
#  array([0.22574076], dtype=float32),
#  array([0.15645133], dtype=float32),
#  array([0.29442343], dtype=float32),
#  array([0.3075852], dtype=float32),
#  array([0.11637761], dtype=float32),
#  array([0.13648324], dtype=float32),
#  array([0.66830105], dtype=float32),
#  array([0.09639471], dtype=float32),
#  array([0.1741578], dtype=float32),
#  array([0.5169615], dtype=float32),
#  array([0.13204649], dtype=float32),
#  array([0.6282645], dtype=float32),
#  array([0.3298948], dtype=float32),
#  array([0.14280719], dtype=float32),
#  array([0.66830105], dtype=float32),
#  array([0.13751358], dtype=float32),
#  array([0.04377444], dtype=float32),
#  array([0.04367901], dtype=float32),
#  array([0.16438381], dtype=float32),
#  array([0.18028845], dtype=float32),
#  array([0.18140718], dtype=float32),
#  array([0.18100314], dtype=float32),
#  array([0.05469234], dtype=float32),
#  array([0.03549131], dtype=float32),
#  array([0.66830105], dtype=float32),
#  array([0.14369158], dtype=float32),
#  array([0.06097736], dtype=float32),
#  array([0.66830105], dtype=float32),
#  array([0.41310912], dtype=float32),
#  array([0.54260963], dtype=float32),
#  array([0.18680915], dtype=float32),
#  array([0.5451713], dtype=float32),
#  array([0.32861358], dtype=float32),
#  array([0.19660804], dtype=float32),
#  array([0.06114405], dtype=float32),
#  array([0.26251528], dtype=float32),
#  array([0.2580996], dtype=float32),
#  array([0.01757758], dtype=float32),
#  array([0.02582585], dtype=float32),
#  array([0.12523526], dtype=float32),
#  array([0.02744251], dtype=float32),
#  array([0.3530365], dtype=float32),
#  array([0.5016339], dtype=float32),
#  array([0.37350774], dtype=float32),
#  array([0.0368703], dtype=float32),
#  array([0.04267029], dtype=float32),
#  array([0.111542], dtype=float32),
#  array([0.05617963], dtype=float32),
#  array([0.05660963], dtype=float32),
#  array([0.6349588], dtype=float32),
#  array([0.06946915], dtype=float32),
#  array([0.05859853], dtype=float32),
#  array([0.16073045], dtype=float32),
#  array([0.25862622], dtype=float32),
#  array([0.04033903], dtype=float32),
#  array([0.10439375], dtype=float32),
#  array([0.04300461], dtype=float32),
#  array([0.09687867], dtype=float32),
#  array([0.3530365], dtype=float32),
#  array([0.39673665], dtype=float32),
#  array([0.1761236], dtype=float32),
#  array([0.05180828], dtype=float32),
#  array([0.06676489], dtype=float32),
#  array([0.02576203], dtype=float32),
#  array([0.46793327], dtype=float32),
#  array([0.66830105], dtype=float32),
#  array([0.6745759], dtype=float32),
#  array([0.66702926], dtype=float32),
#  array([0.10354929], dtype=float32),
#  array([0.20481177], dtype=float32),
#  array([0.01688481], dtype=float32),
#  array([0.1462812], dtype=float32),
#  array([0.05355472], dtype=float32),
#  array([0.43202487], dtype=float32),
#  array([0.10108571], dtype=float32),
#  array([0.24391064], dtype=float32),
#  array([0.25399306], dtype=float32),
#  array([0.18033077], dtype=float32),
#  array([0.1859361], dtype=float32),
#  array([0.04688984], dtype=float32),
#  array([0.09964858], dtype=float32),
#  array([0.13904168], dtype=float32),
#  array([0.8283952], dtype=float32),
#  array([0.04067401], dtype=float32),
#  array([0.2718698], dtype=float32),
#  array([0.33238003], dtype=float32),
#  array([0.12812795], dtype=float32),
#  array([0.174872], dtype=float32),
#  array([0.34468496], dtype=float32),
#  array([0.09376541], dtype=float32),
#  array([0.6935299], dtype=float32),
#  array([0.03641782], dtype=float32),
#  array([0.13707422], dtype=float32),
#  array([0.10433865], dtype=float32),
#  array([0.3530365], dtype=float32),
#  array([0.61557674], dtype=float32),
#  array([0.09361281], dtype=float32),
#  array([0.23775187], dtype=float32),
#  array([0.01968581], dtype=float32),
#  array([0.30014458], dtype=float32),
#  array([0.2988098], dtype=float32),
#  array([0.3530365], dtype=float32),
#  array([0.18710527], dtype=float32),
#  array([0.2728676], dtype=float32),
#  array([0.03221779], dtype=float32),
#  array([0.56424814], dtype=float32),
#  array([0.12944849], dtype=float32),
#  array([0.14902385], dtype=float32),
#  array([0.21991773], dtype=float32),
#  array([0.13013275], dtype=float32),
#  array([0.11973501], dtype=float32),
#  array([0.01648762], dtype=float32),
#  array([0.23933852], dtype=float32),
#  array([0.14245504], dtype=float32),
#  array([0.07000117], dtype=float32),
#  array([0.3530365], dtype=float32),
#  array([0.3530365], dtype=float32),
#  array([0.17016228], dtype=float32),
#  array([0.32616234], dtype=float32),
#  array([0.3057761], dtype=float32),
#  array([0.05237994], dtype=float32),
#  array([0.49189648], dtype=float32),
#  array([0.21672244], dtype=float32),
#  array([0.3530365], dtype=float32),
#  array([0.10516825], dtype=float32),
#  array([0.33610004], dtype=float32),
#  array([0.14939664], dtype=float32),
#  array([0.01362687], dtype=float32),
#  array([0.14793785], dtype=float32),
#  array([0.16682348], dtype=float32),
#  array([0.18865588], dtype=float32),
#  array([0.09447893], dtype=float32),
#  array([0.5602178], dtype=float32),
#  array([0.3063895], dtype=float32),
#  array([0.34875736], dtype=float32),
#  array([0.05895387], dtype=float32),
#  array([0.6247033], dtype=float32),
#  array([0.57845426], dtype=float32),
#  array([0.20252082], dtype=float32),
#  array([0.60001165], dtype=float32),
#  array([0.37784132], dtype=float32),
#  array([0.22113235], dtype=float32),
#  array([0.10351161], dtype=float32),
#  array([0.21645449], dtype=float32),
#  array([0.24961516], dtype=float32),
#  array([0.27427715], dtype=float32),
#  array([0.06788635], dtype=float32),
#  array([0.18061686], dtype=float32),
#  array([0.16138263], dtype=float32),
#  array([0.6148231], dtype=float32),
#  array([0.0574542], dtype=float32),
#  array([0.19554578], dtype=float32),
#  array([0.04481654], dtype=float32),
#  array([0.27538726], dtype=float32),
#  array([0.06927118], dtype=float32),
#  array([0.13300599], dtype=float32),
#  array([0.32395694], dtype=float32),
#  array([0.1126365], dtype=float32),
#  array([0.06233494], dtype=float32),
#  array([0.01175071], dtype=float32),
#  array([0.24804635], dtype=float32),
#  array([0.00867885], dtype=float32),
#  array([0.06892675], dtype=float32),
#  array([0.33472112], dtype=float32),
#  array([0.05221299], dtype=float32),
#  array([0.08982025], dtype=float32),
#  array([0.10521465], dtype=float32),
#  array([0.13337135], dtype=float32),
#  array([0.01775573], dtype=float32),
#  array([0.0365871], dtype=float32),
#  array([0.29373437], dtype=float32),
#  array([0.3530365], dtype=float32),
#  array([0.13903059], dtype=float32),
#  array([0.28023094], dtype=float32),
#  array([0.07722193], dtype=float32),
#  array([0.19614634], dtype=float32),
#  array([0.09244035], dtype=float32),
#  array([0.05065173], dtype=float32),
#  array([0.11951706], dtype=float32),
#  array([0.09563064], dtype=float32),
#  array([0.1088736], dtype=float32),
#  array([0.17619613], dtype=float32),
#  array([0.29263994], dtype=float32),
#  array([0.289513], dtype=float32),
#  array([0.6342147], dtype=float32),
#  array([0.24863814], dtype=float32),
#  array([0.01743461], dtype=float32),
#  array([0.7598106], dtype=float32),
#  array([0.15996142], dtype=float32),
#  array([0.03349762], dtype=float32),
#  array([0.2335614], dtype=float32),
#  array([0.32438427], dtype=float32),
#  array([0.33728984], dtype=float32),
#  array([0.26558062], dtype=float32),
#  array([0.22317943], dtype=float32),
#  array([0.11995864], dtype=float32),
#  array([0.20531932], dtype=float32),
#  array([0.0306387], dtype=float32),
#  array([0.10064293], dtype=float32),
#  array([0.25069848], dtype=float32),
#  array([0.4493813], dtype=float32),
#  array([0.03510065], dtype=float32),
#  array([0.2684342], dtype=float32),
#  array([0.15611179], dtype=float32),
#  array([0.20741303], dtype=float32),
#  array([0.04852338], dtype=float32),
#  array([0.08237606], dtype=float32),
#  array([0.18279392], dtype=float32),
#  array([0.24931052], dtype=float32),
#  array([0.3127776], dtype=float32),
#  array([0.3755745], dtype=float32),
#  array([0.14888158], dtype=float32),
#  array([0.03385222], dtype=float32),
#  array([0.41584978], dtype=float32),
#  array([0.2870762], dtype=float32),
#  array([0.36254758], dtype=float32),
#  array([0.18788382], dtype=float32),
#  array([0.08820642], dtype=float32),
#  array([0.3942201], dtype=float32),
#  array([0.17368285], dtype=float32),
#  array([0.1913834], dtype=float32),
#  array([0.04883423], dtype=float32),
#  array([0.06718483], dtype=float32),
#  array([0.27589592], dtype=float32),
#  array([0.66830105], dtype=float32),
#  array([0.03408275], dtype=float32),
#  array([0.12419207], dtype=float32),
#  array([0.10606935], dtype=float32),
#  array([0.08382729], dtype=float32),
#  array([0.34458157], dtype=float32),
#  array([0.22979735], dtype=float32),
#  array([0.21669175], dtype=float32),
#  array([0.01731335], dtype=float32),
#  array([0.20596203], dtype=float32),
#  array([0.08642359], dtype=float32),
#  array([0.20756467], dtype=float32),
#  array([0.08012506], dtype=float32),
#  array([0.09234661], dtype=float32),
#  array([0.75294495], dtype=float32),
#  array([0.20160471], dtype=float32),
#  array([0.02189692], dtype=float32),
#  array([0.08243281], dtype=float32),
#  array([0.14117077], dtype=float32),
#  array([0.04839647], dtype=float32),
#  array([0.43084264], dtype=float32),
#  array([0.6343719], dtype=float32),
#  array([0.9071169], dtype=float32),
#  array([0.10729668], dtype=float32),
#  array([0.15215784], dtype=float32),
#  array([0.06008522], dtype=float32),
#  array([0.03586838], dtype=float32),
#  array([0.13606039], dtype=float32),
#  array([0.13605894], dtype=float32),
#  array([0.0462787], dtype=float32),
#  array([0.17154586], dtype=float32),
#  array([0.5996935], dtype=float32),
#  array([0.00489056], dtype=float32),
#  array([0.2722713], dtype=float32),
#  array([0.01032079], dtype=float32),
#  array([0.02791922], dtype=float32),
#  array([0.33618522], dtype=float32),
#  array([0.02982545], dtype=float32),
#  array([0.06318526], dtype=float32),
#  array([0.3264613], dtype=float32),
#  array([0.1342613], dtype=float32),
#  array([0.08520814], dtype=float32),
#  array([0.20230825], dtype=float32),
#  array([0.08539543], dtype=float32),
#  array([0.16935404], dtype=float32),
#  array([0.26333126], dtype=float32),
#  array([0.11932146], dtype=float32),
#  array([0.20833641], dtype=float32),
#  array([0.5451138], dtype=float32),
#  array([0.39151612], dtype=float32),
#  array([0.26714566], dtype=float32),
#  array([0.04275899], dtype=float32),
#  array([0.32606938], dtype=float32),
#  array([0.01599141], dtype=float32),
#  array([0.58681774], dtype=float32),
#  array([0.22822379], dtype=float32),
#  array([0.18524322], dtype=float32),
#  array([0.08202682], dtype=float32),
#  array([0.02631117], dtype=float32),
#  array([0.14968164], dtype=float32),
#  array([0.18680802], dtype=float32),
#  array([0.32668826], dtype=float32),
#  array([0.08193078], dtype=float32),
#  array([0.39657754], dtype=float32),
#  array([0.077649], dtype=float32),
#  array([0.03948176], dtype=float32),
#  array([0.03619877], dtype=float32),
#  array([0.04536282], dtype=float32),
#  array([0.25750202], dtype=float32),
#  array([0.17556895], dtype=float32),
#  array([0.09805866], dtype=float32),
#  array([0.04074406], dtype=float32),
#  array([0.01958275], dtype=float32),
#  array([0.22445123], dtype=float32),
#  array([0.25066766], dtype=float32),
#  array([0.03838545], dtype=float32),
#  array([0.34150875], dtype=float32),
#  array([0.2631936], dtype=float32),
#  array([0.18722883], dtype=float32),
#  array([0.011042], dtype=float32),
#  array([0.15928127], dtype=float32),
#  array([0.03910926], dtype=float32),
#  array([0.01477992], dtype=float32),
#  array([0.66830105], dtype=float32),
#  array([0.13971652], dtype=float32),
#  array([0.09418694], dtype=float32),
#  array([0.11157811], dtype=float32),
#  array([0.66830105], dtype=float32),
#  array([0.26705635], dtype=float32),
#  array([0.23828578], dtype=float32),
#  array([0.56467783], dtype=float32),
#  array([0.12231037], dtype=float32),
#  array([0.12475867], dtype=float32),
#  array([0.01503602], dtype=float32),
#  array([0.14361605], dtype=float32),
#  array([0.18543305], dtype=float32),
#  array([0.29924735], dtype=float32),
#  array([0.05121258], dtype=float32),
#  array([0.01462092], dtype=float32),
#  array([0.04819311], dtype=float32),
#  array([0.11191899], dtype=float32),
#  array([0.3023551], dtype=float32),
#  array([0.0358507], dtype=float32),
#  array([0.09158768], dtype=float32),
#  array([0.02572284], dtype=float32),
#  array([0.01733937], dtype=float32),
#  array([0.65213907], dtype=float32),
#  array([0.24023446], dtype=float32),
#  array([0.06750045], dtype=float32),
#  array([0.01765268], dtype=float32),
#  array([0.05195558], dtype=float32),
#  array([0.14967456], dtype=float32),
#  array([0.0642895], dtype=float32),
#  array([0.04673071], dtype=float32),
#  array([0.02902719], dtype=float32),
#  array([0.2538577], dtype=float32),
#  array([0.08941674], dtype=float32),
#  array([0.506583], dtype=float32),
#  array([0.76726705], dtype=float32),
#  array([0.55729336], dtype=float32),
#  array([0.4648922], dtype=float32),
#  array([0.8765228], dtype=float32),
#  array([0.11203939], dtype=float32),
#  array([0.0716752], dtype=float32),
#  array([0.3530365], dtype=float32),
#  array([0.06162604], dtype=float32),
#  array([0.03630411], dtype=float32),
#  array([0.59630495], dtype=float32),
#  array([0.04472807], dtype=float32),
#  array([0.5708363], dtype=float32),
#  array([0.33919817], dtype=float32),
#  array([0.01784802], dtype=float32),
#  array([0.12827818], dtype=float32),
#  array([0.14907926], dtype=float32),
#  array([0.04684487], dtype=float32),
#  array([0.11851764], dtype=float32),
#  array([0.19382684], dtype=float32),
#  array([0.08490027], dtype=float32),
#  array([0.04674238], dtype=float32),
#  array([0.04686726], dtype=float32),
#  array([0.49801096], dtype=float32),
#  array([0.05283864], dtype=float32),
#  array([0.01030099], dtype=float32),
#  array([0.06825072], dtype=float32),
#  array([0.12980899], dtype=float32),
#  array([0.5976049], dtype=float32),
#  array([0.29626194], dtype=float32),
#  array([0.01458913], dtype=float32),
#  array([0.51189595], dtype=float32),
#  array([0.09048544], dtype=float32),
#  array([0.66830105], dtype=float32),
#  array([0.28410804], dtype=float32),
#  array([0.250535], dtype=float32),
#  array([0.07680127], dtype=float32),
#  array([0.6227082], dtype=float32),
#  array([0.19127949], dtype=float32),
#  array([0.21724199], dtype=float32),
#  array([0.28326347], dtype=float32),
#  array([0.12702088], dtype=float32),
#  array([0.04045495], dtype=float32),
#  array([0.2352884], dtype=float32),
#  array([0.08662735], dtype=float32),
#  array([0.4918154], dtype=float32),
#  array([0.11127784], dtype=float32),
#  array([0.17228639], dtype=float32),
#  array([0.07526253], dtype=float32),
#  array([0.12078957], dtype=float32),
#  array([0.6171744], dtype=float32),
#  array([0.5294995], dtype=float32),
#  array([0.0373275], dtype=float32),
#  array([0.16526893], dtype=float32),
#  array([0.2821817], dtype=float32),
#  array([0.03292393], dtype=float32),
#  array([0.24723522], dtype=float32),
#  array([0.10571579], dtype=float32),
#  array([0.07138676], dtype=float32),
#  array([0.34287566], dtype=float32),
#  array([0.6602557], dtype=float32),
#  array([0.04256051], dtype=float32),
#  array([0.1671367], dtype=float32),
#  array([0.10403011], dtype=float32),
#  array([0.24227802], dtype=float32),
#  array([0.07547079], dtype=float32),
#  array([0.10135598], dtype=float32),
#  array([0.69555855], dtype=float32),
#  array([0.22474732], dtype=float32),
#  array([0.01509396], dtype=float32),
#  array([0.21224636], dtype=float32),
#  array([0.1024708], dtype=float32),
#  array([0.06086958], dtype=float32),
#  array([0.09709387], dtype=float32),
#  array([0.01575894], dtype=float32),
#  array([0.22419149], dtype=float32),
#  array([0.01260788], dtype=float32),
#  array([0.21329054], dtype=float32),
#  array([0.2801018], dtype=float32),
#  array([0.3058245], dtype=float32),
#  array([0.30155402], dtype=float32),
#  array([0.08016936], dtype=float32),
#  array([0.5707217], dtype=float32),
#  array([0.044843], dtype=float32),
#  array([0.19880158], dtype=float32),
#  array([0.22947067], dtype=float32),
#  array([0.21079332], dtype=float32),
#  array([0.02773205], dtype=float32),
#  array([0.5390367], dtype=float32),
#  array([0.03042741], dtype=float32),
#  array([0.10093538], dtype=float32),
#  array([0.20482047], dtype=float32),
#  array([0.04406314], dtype=float32),
#  array([0.08702732], dtype=float32),
#  array([0.2572056], dtype=float32),
#  array([0.5309693], dtype=float32),
#  array([0.3530365], dtype=float32),
#  array([0.0230149], dtype=float32),
#  array([0.10629171], dtype=float32),
#  array([0.08896397], dtype=float32),
#  array([0.02479583], dtype=float32),
#  array([0.11655188], dtype=float32),
#  array([0.11588649], dtype=float32),
#  array([0.48386005], dtype=float32),
#  array([0.40441963], dtype=float32),
#  array([0.03098048], dtype=float32),
#  array([0.31611943], dtype=float32),
#  array([0.15693294], dtype=float32),
#  array([0.24036776], dtype=float32),
#  array([0.06822609], dtype=float32),
#  ...]

# %%
y_pred = (y_pred > 0.5)

# %%
probability_prediction = list(y_pred)

# %%
probability_prediction
# Out:
# [array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([ True]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([ True]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([ True]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([ True]),
#  array([ True]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([ True]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  array([False]),
#  ...]

# %% [markdown]
# #### Making the Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix

# %%
cm = confusion_matrix(y_test, y_pred)

# %%
cm
# Out:
# array([[1548,   47],
#        [ 235,  170]], dtype=int64)

# %%
model_accuracy= ((cm[0,0]+cm[0,1])/2000)*100

# %%
print("Model Accuracy=",model_accuracy)
# Out:
# Model Accuracy= 79.75

# %% [markdown]
# #### Predict a single observation

# %%
#Geography: France
#Credit Score: 600
#Gender: Male
#Age: 40 years old
#Tenure: 3 years
#Balance: $60000
#Number of Products: 2
#Does this customer have a credit card ? Yes
#Is this customer an Active Member: Yes
#Estimated Salary: $50000

# %% [markdown]
# ### Process

# %%
# 1)Data should be included in the same order
# 2) Data must be included with the same data type(Encoding)

# %%
new_prediction = classifier.predict(sc.transform(np.array([[0,0,600,1,40,3,60000,2,1,1,50000]])))

# %%
new_prediction= (new_prediction>0.5)

# %%
print(" Will the customer leave the bank=",new_prediction[0])
# Out:
#  Will the customer leave the bank= [False]

# %% [markdown]
# ### Evaluating , Improving and Tuning the ANN

# %%
from keras.wrappers.scikit_learn import KerasClassifier

# %%
from sklearn.model_selection import cross_val_score

# %%
def build_classifier():
    classifier = Sequential()
    classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu', input_dim = 11))
    classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))
    classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))
    classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
    return classifier

# %%
classifier = KerasClassifier(build_fn = build_classifier,batch_size=10,nb_epoch=100)

# %%
accuracies = cross_val_score(estimator=classifier,X=X_train,y=y_train,cv=10,n_jobs=-1)

# %%
accuracies
# Out:
# array([0.78625   , 0.79000002, 0.80000001, 0.78250003, 0.81625003,
#        0.81      , 0.78750002, 0.79374999, 0.79874998, 0.79500002])

# %%
mean=accuracies.mean()
mean
# Out:
# 0.7960000097751617

# %%
variance=accuracies.std()
variance
# Out:
# 0.010105690527913859

# %% [markdown]
# ## Improving the ANN
